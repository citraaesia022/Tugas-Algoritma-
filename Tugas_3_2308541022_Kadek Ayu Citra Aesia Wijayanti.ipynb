# %%
a_22 = 0
while a_22 < 3:
    print(a_22 * '      $')
    print(a_22 * '     $')
    print(a_22 * '    $')
    a_22 += 2
# Out:
#       $      $
#      $     $
#     $    $

# %%
print("notasi angka dalam lagu")
print("do,re,mi,fa,so,la,si")
print("1,2,3,4,5,6,7")
n_22 = 1
while n_22 < 7:
    print("Notasi " + str(n_22)+" masih rendah dari 7")
    n_22 += 1
# Out:
# notasi angka dalam lagu
# do,re,mi,fa,so,la,si
# 1,2,3,4,5,6,7
# Notasi 1 masih rendah dari 7
# Notasi 2 masih rendah dari 7
# Notasi 3 masih rendah dari 7
# Notasi 4 masih rendah dari 7
# Notasi 5 masih rendah dari 7
# Notasi 6 masih rendah dari 7

# %%
berat_badan_22 = float(input("berat badan anda adalah"))
if berat_badan_22 <= 18:
    print("Anda tergolong kurus sekali")
    print("Sebaiknya anda banyak makan lagi")
if berat_badan_22 <= 40 and berat_badan_22 >= 18:
    print("Anda tergolong masih kurus")
    print("Sebaiknya anda lebih banyak makan lagi")
if berat_badan_22 >= 40 and berat_badan_22 <= 60:
    print("Anda tergolong gemuk")
    print("Sebaikknya anda atur pola makan lagi")
if berat_badan_22 >= 60 and berat_badan_22 <= 150:
    print("Anda tergolong gemuk sekali")
    print("Sebaikknya anda ikut program diet")
# Out:
# berat badan anda adalah 14
# Anda tergolong kurus sekali
# Sebaiknya anda banyak makan lagi
