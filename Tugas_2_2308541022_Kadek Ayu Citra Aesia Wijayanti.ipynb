# %%
print('Data 5 suhu pasien RS Citra Mulia dalam celcius')
suhu_pasien_1_104F_22 = 5/9 * (104-32)
suhu_pasien_2_95F_22 = 5/9 * (95-32)
suhu_pasien_3_113F_22 = 5/9 * (113-32)
suhu_pasien_4_86F_22 = 5/9 * (86-32)
suhu_pasien_5_100F_22 = 5/9 * (100-32)
print('Apakah suhu pasien 1 lebih besar dari 30 derajat celcius dan suhu pasien 2 lebih kecil dari 40')
print(suhu_pasien_1_104F_22 > 30 and suhu_pasien_2_95F_22 < 40)
print('Apakah suhu pasien 4 lebih kecil dari 32 derajat celcius dan suhu pasien 5 lebih besar dari 36')
print(suhu_pasien_4_86F_22 < 32 and suhu_pasien_5_100F_22 > 36)
print('Apakah suhu pasien 3 lebih besar dari 50 derajat celcius dan suhu pasien 1 lebih kecil dari 30')
print(suhu_pasien_3_113F_22 > 50 and suhu_pasien_1_104F_22 < 30)
# Out:
# Data 5 suhu pasien RS Citra Mulia dalam celcius
# Apakah suhu pasien 1 lebih besar dari 30 derajat celcius dan suhu pasien 2 lebih kecil dari 40
# True
# Apakah suhu pasien 4 lebih kecil dari 32 derajat celcius dan suhu pasien 5 lebih besar dari 36
# True
# Apakah suhu pasien 3 lebih besar dari 50 derajat celcius dan suhu pasien 1 lebih kecil dari 30
# False

# %%
keterangan_waktu_22 = "pagi tadi"
kegiatan_1_22 = "sudah mentransfer"
keterangan_benda_1_22 = "uang 100rb"
kata_penghubung_22 = " lalu" 
nama_22 = "Intan Karunia Dewi"
kegiatan_2_22 = "juga mentranfer"
keterangan_benda_2_22 = "uang 100rb"
print(keterangan_waktu_22 + ' kakak saya ' + kegiatan_1_22 + ' kepada saya ' + keterangan_benda_1_22 + kata_penghubung_22 + ' sepupu saya ' + nama_22 + ' dia ' + kegiatan_2_22 + ' saya ' + keterangan_benda_2_22 + '.' )
# Out:
# pagi tadi kakak saya sudah mentransfer kepada saya uang 100rb lalu sepupu saya Intan Karunia Dewi dia juga mentranfer saya uang 100rb.

# %%
print('saya ketika kuliah')
keadaan_22 = 'saya setiap hari selalu mengantuk dan terlambat ketika kuliah'
print(keadaan_22[23:34])
print(keadaan_22[2:4])
# Out:
# saya ketika kuliah
#  mengantuk
# ya

# %%
tinggi_mia_22 = 160
tinggi_citra_22 = 173
tinggi_oca_22 = 167
tinggi_ratih_22 = 150
tinggi_diva_22 = 169
tinggi_wirya_22 = 155
tinggi_rivat_22 = 153
tinggi_yuda_22 = 170
tinggi_ari_22 = 159
tinggi_jesya_22 = 173
print('tinggi badan Mia lebih kecil dari tinggi badan Diva')
print(tinggi_mia_22 < tinggi_diva_22)
print('tinggi badan Citra sama dengan tinggi badan Jesya')
print(tinggi_citra_22 == tinggi_jesya_22)
print('tinggi badan Ratih tidak sama dengan tinggi badan Ari')
print(tinggi_ratih_22 != tinggi_ari_22)
print('tinggi badan Yuda lebih kecil sama dengan tinggi badan Rivat')
print(tinggi_yuda_22 <= tinggi_rivat_22)
# Out:
# tinggi badan Mia lebih kecil dari tinggi badan Diva
# True
# tinggi badan Citra sama dengan tinggi badan Jesya
# True
# tinggi badan Ratih tidak sama dengan tinggi badan Ari
# True
# tinggi badan Yuda lebih kecil sama dengan tinggi badan Rivat
# False

# %%
Kalimat_22='Sangeh adalah tempat tinggal saya'
Kalimat_22.replace('Sangeh','Denpasar')
# Out:
# 'Denpasar adalah tempat tinggal saya'

# %%
Kalimat_22.upper()
# Out:
# 'SANGEH ADALAH TEMPAT TINGGAL SAYA'

# %%
print('Bali' in Kalimat_22)
# Out:
# False
